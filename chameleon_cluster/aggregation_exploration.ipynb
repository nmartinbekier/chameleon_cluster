# %%
import pandas as pd

from visualization import *
from chameleon import *

# %% [markdown]
# # Comments about parameters
# * Reduced alpha to 1.5 and knn to 15, so that bottom circle won't connect with bottom of upper left moon
# * Smaller values of knn merge a portion of the blue left middle circle with the big yellow circle

# %%
df = pd.read_csv('./datasets/Aggregation.csv', sep=' ', header=None)

# returns a pands.dataframe of cluster
res = cluster(df, 7, knn=15, m=40, alpha=1.5, verbose=True, plot=True)
# Out:
# Building kNN graph (k = 15)...
# 100%|██████████| 788/788 [00:03<00:00, 250.45it/s]
# Begin clustering...
#   0%|          | 0/33 [00:00<?, ?it/s]
# Checking c0 with...
# c1, c2, c3, c4, c5, ...
# Found connecting edges between c0 and c5
# Merge score: 0.020807
# Better than: 0.000000
# ..., c6, c7, c8, c9, c10, c11, c12, c13, c14, ...
# Found connecting edges between c0 and c14
# Merge score: 0.721901
# Better than: 0.020807
# ..., c15, c16, c17, ...
# Found connecting edges between c0 and c17
# Merge score: 0.137098
# ..., c18, ...
# Found connecting edges between c0 and c18
# Merge score: 1.469775
# Better than: 0.721901
# ..., c19, c20, c21, ...
# Found connecting edges between c0 and c21
# Merge score: 1.363032
# ..., c22, c23, c24, c25, c26, c27, ...
# Found connecting edges between c0 and c27
# Merge score: 0.545907
# ..., c28, c29, c30, ...
# Found connecting edges between c0 and c30
# Merge score: 0.202118
# ..., c31, c32, c33, c34, c35, c36, c37, ...
# Found connecting edges between c0 and c37
# Merge score: 0.858185
#
# Checking c1 with...
# c2, c3, c4, c5, c6, c7, c8, c9, c10, c11, c12, c13, c14, c15, c16, c17, c18, c19, c20, c21, c22, c23, c24, c25, c26, c27, c28, c29, c30, c31, c32, c33, ...
# Found connecting edges between c1 and c33
# Merge score: 1.583181
# Better than: 1.469775
#
# Checking c2 with...
# c3, c4, c5, c6, c7, c8, c9, c10, c11, ...
# Found connecting edges between c2 and c11
# Merge score: 1.270592
# ..., c12, c13, c14, c15, c16, c17, c18, c19, ...
# Found connecting edges between c2 and c19
# Merge score: 0.117805
# ..., c20, c21, c22, c23, c24, c25, c26, ...
# Found connecting edges between c2 and c26
# Merge score: 1.691403
# Better than: 1.583181
#
# Checking c3 with...
# c4, c5, c6, c7, c8, c9, c10, c11, c12, c13, c14, c15, c16, c17, c18, c19, c20, c21, c22, c23, c24, c25, c26, c27, ...
# Found connecting edges between c3 and c27
# Merge score: 0.326077
# ..., c28, c29, c30, c31, ...
# Found connecting edges between c3 and c31
# Merge score: 2.049393
# Better than: 1.691403
#
# Checking c4 with...
# c5, c6, c7, c8, c9, c10, c11, c12, c13, c14, c15, c16, c17, c18, c19, c20, c21, c22, ...
# Found connecting edges between c4 and c22
# Merge score: 0.892151
# ..., c23, c24, ...
# Found connecting edges between c4 and c24
# Merge score: 0.017291
# ..., c25, c26, c27, c28, c29, c30, c31, c32, c33, c34, c35, c36, c37, c38, ...
# Found connecting edges between c4 and c38
# Merge score: 0.574479
# ..., c39, ...
# Found connecting edges between c4 and c39
# Merge score: 1.120681
#
# Checking c5 with...
# c6, c7, c8, c9, ...
# Found connecting edges between c5 and c9
# Merge score: 0.309983
# ..., c10, ...
# Found connecting edges between c5 and c10
# Merge score: 0.607033
# ..., c11, c12, c13, c14, c15, c16, c17, ...
# Found connecting edges between c5 and c17
# Merge score: 1.326595
# ..., c18, ...
# Found connecting edges between c5 and c18
# Merge score: 1.040453
# ..., c19, c20, c21, c22, c23, c24, c25, c26, c27, c28, ...
# Found connecting edges between c5 and c28
# Merge score: 2.945112
# Better than: 2.049393
#
# Checking c6 with...
# c7, c8, c9, c10, c11, c12, c13, ...
# Found connecting edges between c6 and c13
# Merge score: 0.898897
# ..., c14, c15, c16, c17, c18, c19, c20, c21, c22, c23, ...
# Found connecting edges between c6 and c23
# Merge score: 0.394068
# ..., c24, c25, c26, c27, c28, c29, c30, c31, c32, c33, c34, c35, c36, ...
# Found connecting edges between c6 and c36
# Merge score: 1.227294
#
# Checking c7 with...
# c8, c9, c10, c11, c12, c13, c14, c15, c16, c17, c18, c19, c20, c21, c22, c23, c24, c25, c26, c27, c28, c29, c30, c31, c32, c33, c34, ...
# Found connecting edges between c7 and c34
# Merge score: 1.626234
#
# Checking c8 with...
# c9, c10, c11, c12, c13, c14, c15, c16, ...
# Found connecting edges between c8 and c16
# Merge score: 1.526875
# ..., c17, c18, c19, c20, c21, c22, c23, c24, ...
# Found connecting edges between c8 and c24
# Merge score: 0.193762
# ..., c25, c26, c27, c28, c29, c30, c31, c32, c33, c34, c35, c36, c37, c38, c39, ...
# Found connecting edges between c8 and c39
# Merge score: 1.829022
#
# Checking c9 with...
# c10, c11, c12, c13, c14, c15, c16, c17, ...
# Found connecting edges between c9 and c17
# Merge score: 0.662020
# ..., c18, c19, c20, c21, c22, c23, c24, c25, c26, c27, c28, ...
# Found connecting edges between c9 and c28
# Merge score: 0.961950
# ..., c29, ...
# Found connecting edges between c9 and c29
# Merge score: 0.730529
#
# Checking c10 with...
# c11, c12, c13, c14, c15, c16, c17, c18, ...
# Found connecting edges between c10 and c18
# Merge score: 0.673215
# ..., c19, c20, c21, c22, c23, c24, c25, c26, c27, c28, ...
# Found connecting edges between c10 and c28
# Merge score: 0.733469
# ..., c29, c30, ...
# Found connecting edges between c10 and c30
# Merge score: 1.224740
#
# Checking c11 with...
# c12, c13, c14, c15, c16, ...
# Found connecting edges between c11 and c16
# Merge score: 0.007173
# ..., c17, c18, c19, ...
# Found connecting edges between c11 and c19
# Merge score: 0.531685
# ..., c20, c21, c22, c23, c24, c25, c26, ...
# Found connecting edges between c11 and c26
# Merge score: 0.050802
# ..., c27, c28, c29, c30, c31, c32, ...
# Found connecting edges between c11 and c32
# Merge score: 1.046928
#
# Checking c12 with...
# c13, c14, c15, c16, c17, c18, c19, c20, ...
# Found connecting edges between c12 and c20
# Merge score: 0.202955
# ..., c21, c22, c23, ...
# Found connecting edges between c12 and c23
# Merge score: 0.339124
# ..., c24, c25, c26, c27, c28, c29, c30, c31, c32, c33, ...
# Found connecting edges between c12 and c33
# Merge score: 1.528766
# ..., c34, c35, ...
# Found connecting edges between c12 and c35
# Merge score: 1.130192
#
# Checking c13 with...
# c14, c15, c16, c17, c18, c19, c20, c21, c22, c23, ...
# Found connecting edges between c13 and c23
# Merge score: 0.764793
#
# Checking c14 with...
# c15, c16, c17, c18, c19, c20, c21, c22, c23, c24, c25, c26, c27, ...
# Found connecting edges between c14 and c27
# Merge score: 1.133190
# ..., c28, c29, c30, c31, c32, c33, c34, c35, c36, c37, ...
# Found connecting edges between c14 and c37
# Merge score: 0.705070
#
# Checking c15 with...
# c16, c17, c18, c19, c20, c21, c22, c23, c24, c25, ...
# Found connecting edges between c15 and c25
# Merge score: 1.198138
#
# Checking c16 with...
# c17, c18, c19, c20, c21, c22, c23, c24, ...
# Found connecting edges between c16 and c24
# Merge score: 1.301812
# ..., c25, c26, c27, c28, c29, c30, c31, c32, ...
# Found connecting edges between c16 and c32
# Merge score: 0.281282
# ..., c33, c34, c35, c36, c37, c38, c39, ...
# Found connecting edges between c16 and c39
# Merge score: 0.097993
#
# Checking c17 with...
# c18, ...
# Found connecting edges between c17 and c18
# Merge score: 0.266469
# ..., c19, c20, c21, ...
# Found connecting edges between c17 and c21
# Merge score: 0.471926
# ..., c22, c23, c24, c25, c26, c27, c28, c29, ...
# Found connecting edges between c17 and c29
# Merge score: 1.705780
#
# Checking c18 with...
# c19, c20, c21, ...
# Found connecting edges between c18 and c21
# Merge score: 0.025581
# ..., c22, c23, c24, c25, c26, c27, ...
# Found connecting edges between c18 and c27
# Merge score: 0.019258
# ..., c28, c29, c30, ...
# Found connecting edges between c18 and c30
# Merge score: 1.531350
#
# Checking c19 with...
# c20, c21, c22, c23, c24, c25, c26, ...
# Found connecting edges between c19 and c26
# Merge score: 1.052351
# ..., c27, c28, c29, c30, c31, c32, ...
# Found connecting edges between c19 and c32
# Merge score: 1.142789
#
# Checking c20 with...
# c21, c22, c23, ...
# Found connecting edges between c20 and c23
# Merge score: 0.152687
# ..., c24, c25, c26, c27, c28, c29, c30, c31, c32, c33, c34, c35, ...
# Found connecting edges between c20 and c35
# Merge score: 1.302509
# ..., c36, ...
# Found connecting edges between c20 and c36
# Merge score: 1.520098
#
# Checking c21 with...
# c22, c23, c24, c25, c26, c27, c28, c29, ...
# Found connecting edges between c21 and c29
# Merge score: 1.016531
# ..., c30, c31, c32, c33, c34, c35, c36, c37, ...
# Found connecting edges between c21 and c37
# Merge score: 1.232921
#
# Checking c22 with...
# c23, c24, c25, c26, c27, c28, c29, c30, c31, c32, c33, c34, c35, c36, c37, c38, ...
# Found connecting edges between c22 and c38
# Merge score: 1.029239
#
# Checking c23 with...
# c24, c25, c26, c27, c28, c29, c30, c31, c32, c33, ...
# Found connecting edges between c23 and c33
# Merge score: 0.987662
# ..., c34, c35, c36, ...
# Found connecting edges between c23 and c36
# Merge score: 1.334870
#
# Checking c24 with...
# c25, c26, c27, c28, c29, c30, c31, c32, c33, c34, c35, c36, c37, c38, ...
# Found connecting edges between c24 and c38
# Merge score: 0.754396
# ..., c39, ...
# Found connecting edges between c24 and c39
# Merge score: 0.563960
#
# Checking c25 with...
#
# Checking c26 with...
#
# Checking c27 with...
# c28, c29, c30, ...
# Found connecting edges between c27 and c30
# Merge score: 1.493623
#
# Checking c28 with...
#
# Checking c29 with...
# c30, c31, c32, c33, c34, c35, c36, c37, ...
# Found connecting edges between c29 and c37
# Merge score: 0.288049
#
# Checking c30 with...
#
# Checking c31 with...
#
# Checking c32 with...
#
# Checking c33 with...
#
# Checking c34 with...
#
# Checking c35 with...
#
# Checking c36 with...
#
# Checking c37 with...
#
# Checking c38 with...
# c39, ...
# Found connecting edges between c38 and c39
# Merge score: 0.129071
# Merging c5 and c28
#   3%|▎         | 1/33 [00:01<00:59,  1.85s/it]
# Checking c0 with...
# c1, c2, c3, c4, c5, ...
# Found connecting edges between c0 and c5
# Merge score: 0.011645
# Better than: 0.000000
# ..., c6, c7, c8, c9, c10, c11, c12, c13, c14, ...
# Found connecting edges between c0 and c14
# Merge score: 0.721901
# Better than: 0.011645
# ..., c15, c16, c17, ...
# Found connecting edges between c0 and c17
# Merge score: 0.137098
# ..., c18, ...
# Found connecting edges between c0 and c18
# Merge score: 1.469775
# Better than: 0.721901
# ..., c19, c20, c21, ...
# Found connecting edges between c0 and c21
# Merge score: 1.363032
# ..., c22, c23, c24, c25, c26, c27, ...
# Found connecting edges between c0 and c27
# Merge score: 0.545907
# ..., c29, c30, ...
# Found connecting edges between c0 and c30
# Merge score: 0.202118
# ..., c31, c32, c33, c34, c35, c36, c37, ...
# Found connecting edges between c0 and c37
# Merge score: 0.858185
#
# Checking c1 with...
# c2, c3, c4, c5, c6, c7, c8, c9, c10, c11, c12, c13, c14, c15, c16, c17, c18, c19, c20, c21, c22, c23, c24, c25, c26, c27, c29, c30, c31, c32, c33, ...
# Found connecting edges between c1 and c33
# Merge score: 1.583181
# Better than: 1.469775
#
# Checking c2 with...
# c3, c4, c5, c6, c7, c8, c9, c10, c11, ...
# Found connecting edges between c2 and c11
# Merge score: 1.270592
# ..., c12, c13, c14, c15, c16, c17, c18, c19, ...
# Found connecting edges between c2 and c19
# Merge score: 0.117805
# ..., c20, c21, c22, c23, c24, c25, c26, ...
# Found connecting edges between c2 and c26
# Merge score: 1.691403
# Better than: 1.583181
#
# Checking c3 with...
# c4, c5, c6, c7, c8, c9, c10, c11, c12, c13, c14, c15, c16, c17, c18, c19, c20, c21, c22, c23, c24, c25, c26, c27, ...
# Found connecting edges between c3 and c27
# Merge score: 0.326077
# ..., c29, c30, c31, ...
# Found connecting edges between c3 and c31
# Merge score: 2.049393
# Better than: 1.691403
#
# Checking c4 with...
# c5, c6, c7, c8, c9, c10, c11, c12, c13, c14, c15, c16, c17, c18, c19, c20, c21, c22, ...
# Found connecting edges between c4 and c22
# Merge score: 0.892151
# ..., c23, c24, ...
# Found connecting edges between c4 and c24
# Merge score: 0.017291
# ..., c25, c26, c27, c29, c30, c31, c32, c33, c34, c35, c36, c37, c38, ...
# Found connecting edges between c4 and c38
# Merge score: 0.574479
# ..., c39, ...
# Found connecting edges between c4 and c39
# Merge score: 1.120681
#
# Checking c5 with...
# c6, c7, c8, c9, ...
# Found connecting edges between c5 and c9
# Merge score: 0.735919
# ..., c10, ...
# Found connecting edges between c5 and c10
# Merge score: 0.739349
# ..., c11, c12, c13, c14, c15, c16, c17, ...
# Found connecting edges between c5 and c17
# Merge score: 0.694861
# ..., c18, ...
# Found connecting edges between c5 and c18
# Merge score: 0.523832
#
# Checking c6 with...
# c7, c8, c9, c10, c11, c12, c13, ...
# Found connecting edges between c6 and c13
# Merge score: 0.898897
# ..., c14, c15, c16, c17, c18, c19, c20, c21, c22, c23, ...
# Found connecting edges between c6 and c23
# Merge score: 0.394068
# ..., c24, c25, c26, c27, c29, c30, c31, c32, c33, c34, c35, c36, ...
# Found connecting edges between c6 and c36
# Merge score: 1.227294
#
# Checking c7 with...
# c8, c9, c10, c11, c12, c13, c14, c15, c16, c17, c18, c19, c20, c21, c22, c23, c24, c25, c26, c27, c29, c30, c31, c32, c33, c34, ...
# Found connecting edges between c7 and c34
# Merge score: 1.626234
#
# Checking c8 with...
# c9, c10, c11, c12, c13, c14, c15, c16, ...
# Found connecting edges between c8 and c16
# Merge score: 1.526875
# ..., c17, c18, c19, c20, c21, c22, c23, c24, ...
# Found connecting edges between c8 and c24
# Merge score: 0.193762
# ..., c25, c26, c27, c29, c30, c31, c32, c33, c34, c35, c36, c37, c38, c39, ...
# Found connecting edges between c8 and c39
# Merge score: 1.829022
#
# Checking c9 with...
# c10, c11, c12, c13, c14, c15, c16, c17, ...
# Found connecting edges between c9 and c17
# Merge score: 0.662020
# ..., c18, c19, c20, c21, c22, c23, c24, c25, c26, c27, c29, ...
# Found connecting edges between c9 and c29
# Merge score: 0.730529
#
# Checking c10 with...
# c11, c12, c13, c14, c15, c16, c17, c18, ...
# Found connecting edges between c10 and c18
# Merge score: 0.673215
# ..., c19, c20, c21, c22, c23, c24, c25, c26, c27, c29, c30, ...
# Found connecting edges between c10 and c30
# Merge score: 1.224740
#
# Checking c11 with...
# c12, c13, c14, c15, c16, ...
# Found connecting edges between c11 and c16
# Merge score: 0.007173
# ..., c17, c18, c19, ...
# Found connecting edges between c11 and c19
# Merge score: 0.531685
# ..., c20, c21, c22, c23, c24, c25, c26, ...
# Found connecting edges between c11 and c26
# Merge score: 0.050802
# ..., c27, c29, c30, c31, c32, ...
# Found connecting edges between c11 and c32
# Merge score: 1.046928
#
# Checking c12 with...
# c13, c14, c15, c16, c17, c18, c19, c20, ...
# Found connecting edges between c12 and c20
# Merge score: 0.202955
# ..., c21, c22, c23, ...
# Found connecting edges between c12 and c23
# Merge score: 0.339124
# ..., c24, c25, c26, c27, c29, c30, c31, c32, c33, ...
# Found connecting edges between c12 and c33
# Merge score: 1.528766
# ..., c34, c35, ...
# Found connecting edges between c12 and c35
# Merge score: 1.130192
#
# Checking c13 with...
# c14, c15, c16, c17, c18, c19, c20, c21, c22, c23, ...
# Found connecting edges between c13 and c23
# Merge score: 0.764793
#
# Checking c14 with...
# c15, c16, c17, c18, c19, c20, c21, c22, c23, c24, c25, c26, c27, ...
# Found connecting edges between c14 and c27
# Merge score: 1.133190
# ..., c29, c30, c31, c32, c33, c34, c35, c36, c37, ...
# Found connecting edges between c14 and c37
# Merge score: 0.705070
#
# Checking c15 with...
# c16, c17, c18, c19, c20, c21, c22, c23, c24, c25, ...
# Found connecting edges between c15 and c25
# Merge score: 1.198138
#
# Checking c16 with...
# c17, c18, c19, c20, c21, c22, c23, c24, ...
# Found connecting edges between c16 and c24
# Merge score: 1.301812
# ..., c25, c26, c27, c29, c30, c31, c32, ...
# Found connecting edges between c16 and c32
# Merge score: 0.281282
# ..., c33, c34, c35, c36, c37, c38, c39, ...
# Found connecting edges between c16 and c39
# Merge score: 0.097993
#
# Checking c17 with...
# c18, ...
# Found connecting edges between c17 and c18
# Merge score: 0.266469
# ..., c19, c20, c21, ...
# Found connecting edges between c17 and c21
# Merge score: 0.471926
# ..., c22, c23, c24, c25, c26, c27, c29, ...
# Found connecting edges between c17 and c29
# Merge score: 1.705780
#
# Checking c18 with...
# c19, c20, c21, ...
# Found connecting edges between c18 and c21
# Merge score: 0.025581
# ..., c22, c23, c24, c25, c26, c27, ...
# Found connecting edges between c18 and c27
# Merge score: 0.019258
# ..., c29, c30, ...
# Found connecting edges between c18 and c30
# Merge score: 1.531350
#
# Checking c19 with...
# c20, c21, c22, c23, c24, c25, c26, ...
# Found connecting edges between c19 and c26
# Merge score: 1.052351
# ..., c27, c29, c30, c31, c32, ...
# Found connecting edges between c19 and c32
# Merge score: 1.142789
#
# Checking c20 with...
# c21, c22, c23, ...
# Found connecting edges between c20 and c23
# Merge score: 0.152687
# ..., c24, c25, c26, c27, c29, c30, c31, c32, c33, c34, c35, ...
# Found connecting edges between c20 and c35
# Merge score: 1.302509
# ..., c36, ...
# Found connecting edges between c20 and c36
# Merge score: 1.520098
#
# Checking c21 with...
# c22, c23, c24, c25, c26, c27, c29, ...
# Found connecting edges between c21 and c29
# Merge score: 1.016531
# ..., c30, c31, c32, c33, c34, c35, c36, c37, ...
# Found connecting edges between c21 and c37
# Merge score: 1.232921
#
# Checking c22 with...
# c23, c24, c25, c26, c27, c29, c30, c31, c32, c33, c34, c35, c36, c37, c38, ...
# Found connecting edges between c22 and c38
# Merge score: 1.029239
#
# Checking c23 with...
# c24, c25, c26, c27, c29, c30, c31, c32, c33, ...
# Found connecting edges between c23 and c33
# Merge score: 0.987662
# ..., c34, c35, c36, ...
# Found connecting edges between c23 and c36
# Merge score: 1.334870
#
# Checking c24 with...
# c25, c26, c27, c29, c30, c31, c32, c33, c34, c35, c36, c37, c38, ...
# Found connecting edges between c24 and c38
# Merge score: 0.754396
# ..., c39, ...
# Found connecting edges between c24 and c39
# Merge score: 0.563960
#
# Checking c25 with...
#
# Checking c26 with...
#
# Checking c27 with...
# c29, c30, ...
# Found connecting edges between c27 and c30
# Merge score: 1.493623
#
# Checking c29 with...
# c30, c31, c32, c33, c34, c35, c36, c37, ...
# Found connecting edges between c29 and c37
# Merge score: 0.288049
#
# Checking c30 with...
#
# Checking c31 with...
#
# Checking c32 with...
#
# Checking c33 with...
#
# Checking c34 with...
#
# Checking c35 with...
#
# Checking c36 with...
#
# Checking c37 with...
#
# Checking c38 with...
# c39, ...
# Found connecting edges between c38 and c39
# Merge score: 0.129071
# Merging c3 and c31
#   6%|▌         | 2/33 [00:03<00:54,  1.75s/it]
# Checking c0 with...
# c1, c2, c3, c4, c5, ...
# Found connecting edges between c0 and c5
# Merge score: 0.011645
# Better than: 0.000000
# ..., c6, c7, c8, c9, c10, c11, c12, c13, c14, ...
# Found connecting edges between c0 and c14
# Merge score: 0.721901
# Better than: 0.011645
# ..., c15, c16, c17, ...
# Found connecting edges between c0 and c17
# Merge score: 0.137098
# ..., c18, ...
# Found connecting edges between c0 and c18
# Merge score: 1.469775
# Better than: 0.721901
# ..., c19, c20, c21, ...
# Found connecting edges between c0 and c21
# Merge score: 1.363032
# ..., c22, c23, c24, c25, c26, c27, ...
# Found connecting edges between c0 and c27
# Merge score: 0.545907
# ..., c29, c30, ...
# Found connecting edges between c0 and c30
# Merge score: 0.202118
# ..., c32, c33, c34, c35, c36, c37, ...
# Found connecting edges between c0 and c37
# Merge score: 0.858185
#
# Checking c1 with...
# c2, c3, c4, c5, c6, c7, c8, c9, c10, c11, c12, c13, c14, c15, c16, c17, c18, c19, c20, c21, c22, c23, c24, c25, c26, c27, c29, c30, c32, c33, ...
# Found connecting edges between c1 and c33
# Merge score: 1.583181
# Better than: 1.469775
#
# Checking c2 with...
# c3, c4, c5, c6, c7, c8, c9, c10, c11, ...
# Found connecting edges between c2 and c11
# Merge score: 1.270592
# ..., c12, c13, c14, c15, c16, c17, c18, c19, ...
# Found connecting edges between c2 and c19
# Merge score: 0.117805
# ..., c20, c21, c22, c23, c24, c25, c26, ...
# Found connecting edges between c2 and c26
# Merge score: 1.691403
# Better than: 1.583181
#
# Checking c3 with...
# c4, c5, c6, c7, c8, c9, c10, c11, c12, c13, c14, c15, c16, c17, c18, c19, c20, c21, c22, c23, c24, c25, c26, c27, ...
# Found connecting edges between c3 and c27
# Merge score: 0.184644
#
# Checking c4 with...
# c5, c6, c7, c8, c9, c10, c11, c12, c13, c14, c15, c16, c17, c18, c19, c20, c21, c22, ...
# Found connecting edges between c4 and c22
# Merge score: 0.892151
# ..., c23, c24, ...
# Found connecting edges between c4 and c24
# Merge score: 0.017291
# ..., c25, c26, c27, c29, c30, c32, c33, c34, c35, c36, c37, c38, ...
# Found connecting edges between c4 and c38
# Merge score: 0.574479
# ..., c39, ...
# Found connecting edges between c4 and c39
# Merge score: 1.120681
#
# Checking c5 with...
# c6, c7, c8, c9, ...
# Found connecting edges between c5 and c9
# Merge score: 0.735919
# ..., c10, ...
# Found connecting edges between c5 and c10
# Merge score: 0.739349
# ..., c11, c12, c13, c14, c15, c16, c17, ...
# Found connecting edges between c5 and c17
# Merge score: 0.694861
# ..., c18, ...
# Found connecting edges between c5 and c18
# Merge score: 0.523832
#
# Checking c6 with...
# c7, c8, c9, c10, c11, c12, c13, ...
# Found connecting edges between c6 and c13
# Merge score: 0.898897
# ..., c14, c15, c16, c17, c18, c19, c20, c21, c22, c23, ...
# Found connecting edges between c6 and c23
# Merge score: 0.394068
# ..., c24, c25, c26, c27, c29, c30, c32, c33, c34, c35, c36, ...
# Found connecting edges between c6 and c36
# Merge score: 1.227294
#
# Checking c7 with...
# c8, c9, c10, c11, c12, c13, c14, c15, c16, c17, c18, c19, c20, c21, c22, c23, c24, c25, c26, c27, c29, c30, c32, c33, c34, ...
# Found connecting edges between c7 and c34
# Merge score: 1.626234
#
# Checking c8 with...
# c9, c10, c11, c12, c13, c14, c15, c16, ...
# Found connecting edges between c8 and c16
# Merge score: 1.526875
# ..., c17, c18, c19, c20, c21, c22, c23, c24, ...
# Found connecting edges between c8 and c24
# Merge score: 0.193762
# ..., c25, c26, c27, c29, c30, c32, c33, c34, c35, c36, c37, c38, c39, ...
# Found connecting edges between c8 and c39
# Merge score: 1.829022
# Better than: 1.691403
#
# Checking c9 with...
# c10, c11, c12, c13, c14, c15, c16, c17, ...
# Found connecting edges between c9 and c17
# Merge score: 0.662020
# ..., c18, c19, c20, c21, c22, c23, c24, c25, c26, c27, c29, ...
# Found connecting edges between c9 and c29
# Merge score: 0.730529
#
# Checking c10 with...
# c11, c12, c13, c14, c15, c16, c17, c18, ...
# Found connecting edges between c10 and c18
# Merge score: 0.673215
# ..., c19, c20, c21, c22, c23, c24, c25, c26, c27, c29, c30, ...
# Found connecting edges between c10 and c30
# Merge score: 1.224740
#
# Checking c11 with...
# c12, c13, c14, c15, c16, ...
# Found connecting edges between c11 and c16
# Merge score: 0.007173
# ..., c17, c18, c19, ...
# Found connecting edges between c11 and c19
# Merge score: 0.531685
# ..., c20, c21, c22, c23, c24, c25, c26, ...
# Found connecting edges between c11 and c26
# Merge score: 0.050802
# ..., c27, c29, c30, c32, ...
# Found connecting edges between c11 and c32
# Merge score: 1.046928
#
# Checking c12 with...
# c13, c14, c15, c16, c17, c18, c19, c20, ...
# Found connecting edges between c12 and c20
# Merge score: 0.202955
# ..., c21, c22, c23, ...
# Found connecting edges between c12 and c23
# Merge score: 0.339124
# ..., c24, c25, c26, c27, c29, c30, c32, c33, ...
# Found connecting edges between c12 and c33
# Merge score: 1.528766
# ..., c34, c35, ...
# Found connecting edges between c12 and c35
# Merge score: 1.130192
#
# Checking c13 with...
# c14, c15, c16, c17, c18, c19, c20, c21, c22, c23, ...
# Found connecting edges between c13 and c23
# Merge score: 0.764793
#
# Checking c14 with...
# c15, c16, c17, c18, c19, c20, c21, c22, c23, c24, c25, c26, c27, ...
# Found connecting edges between c14 and c27
# Merge score: 1.133190
# ..., c29, c30, c32, c33, c34, c35, c36, c37, ...
# Found connecting edges between c14 and c37
# Merge score: 0.705070
#
# Checking c15 with...
# c16, c17, c18, c19, c20, c21, c22, c23, c24, c25, ...
# Found connecting edges between c15 and c25
# Merge score: 1.198138
#
# Checking c16 with...
# c17, c18, c19, c20, c21, c22, c23, c24, ...
# Found connecting edges between c16 and c24
# Merge score: 1.301812
# ..., c25, c26, c27, c29, c30, c32, ...
# Found connecting edges between c16 and c32
# Merge score: 0.281282
# ..., c33, c34, c35, c36, c37, c38, c39, ...
# Found connecting edges between c16 and c39
# Merge score: 0.097993
#
# Checking c17 with...
# c18, ...
# Found connecting edges between c17 and c18
# Merge score: 0.266469
# ..., c19, c20, c21, ...
# Found connecting edges between c17 and c21
# Merge score: 0.471926
# ..., c22, c23, c24, c25, c26, c27, c29, ...
# Found connecting edges between c17 and c29
# Merge score: 1.705780
#
# Checking c18 with...
# c19, c20, c21, ...
# Found connecting edges between c18 and c21
# Merge score: 0.025581
# ..., c22, c23, c24, c25, c26, c27, ...
# Found connecting edges between c18 and c27
# Merge score: 0.019258
# ..., c29, c30, ...
# Found connecting edges between c18 and c30
# Merge score: 1.531350
#
# Checking c19 with...
# c20, c21, c22, c23, c24, c25, c26, ...
# Found connecting edges between c19 and c26
# Merge score: 1.052351
# ..., c27, c29, c30, c32, ...
# Found connecting edges between c19 and c32
# Merge score: 1.142789
#
# Checking c20 with...
# c21, c22, c23, ...
# Found connecting edges between c20 and c23
# Merge score: 0.152687
# ..., c24, c25, c26, c27, c29, c30, c32, c33, c34, c35, ...
# Found connecting edges between c20 and c35
# Merge score: 1.302509
# ..., c36, ...
# Found connecting edges between c20 and c36
# Merge score: 1.520098
#
# Checking c21 with...
# c22, c23, c24, c25, c26, c27, c29, ...
# Found connecting edges between c21 and c29
# Merge score: 1.016531
# ..., c30, c32, c33, c34, c35, c36, c37, ...
# Found connecting edges between c21 and c37
# Merge score: 1.232921
#
# Checking c22 with...
# c23, c24, c25, c26, c27, c29, c30, c32, c33, c34, c35, c36, c37, c38, ...
# Found connecting edges between c22 and c38
# Merge score: 1.029239
#
# Checking c23 with...
# c24, c25, c26, c27, c29, c30, c32, c33, ...
# Found connecting edges between c23 and c33
# Merge score: 0.987662
# ..., c34, c35, c36, ...
# Found connecting edges between c23 and c36
# Merge score: 1.334870
#
# Checking c24 with...
# c25, c26, c27, c29, c30, c32, c33, c34, c35, c36, c37, c38, ...
# Found connecting edges between c24 and c38
# Merge score: 0.754396
# ..., c39, ...
# Found connecting edges between c24 and c39
# Merge score: 0.563960
#
# Checking c25 with...
#
# Checking c26 with...
#
# Checking c27 with...
# c29, c30, ...
# Found connecting edges between c27 and c30
# Merge score: 1.493623
#
# Checking c29 with...
# c30, c32, c33, c34, c35, c36, c37, ...
# Found connecting edges between c29 and c37
# Merge score: 0.288049
#
# Checking c30 with...
#
# Checking c32 with...
#
# Checking c33 with...
#
# Checking c34 with...
#
# Checking c35 with...
#
# Checking c36 with...
#
# Checking c37 with...
#
# Checking c38 with...
# c39, ...
# Found connecting edges between c38 and c39
# Merge score: 0.129071
# Merging c8 and c39
#   9%|▉         | 3/33 [00:05<00:55,  1.85s/it]
# Checking c0 with...
# c1, c2, c3, c4, c5, ...
# Found connecting edges between c0 and c5
# Merge score: 0.011645
# Better than: 0.000000
# ..., c6, c7, c8, c9, c10, c11, c12, c13, c14, ...
# Found connecting edges between c0 and c14
# Merge score: 0.721901
# Better than: 0.011645
# ..., c15, c16, c17, ...
# Found connecting edges between c0 and c17
# Merge score: 0.137098
# ..., c18, ...
# Found connecting edges between c0 and c18
# Merge score: 1.469775
# Better than: 0.721901
# ..., c19, c20, c21, ...
# Found connecting edges between c0 and c21
# Merge score: 1.363032
# ..., c22, c23, c24, c25, c26, c27, ...
# Found connecting edges between c0 and c27
# Merge score: 0.545907
# ..., c29, c30, ...
# Found connecting edges between c0 and c30
# Merge score: 0.202118
# ..., c32, c33, c34, c35, c36, c37, ...
# Found connecting edges between c0 and c37
# Merge score: 0.858185
#
# Checking c1 with...
# c2, c3, c4, c5, c6, c7, c8, c9, c10, c11, c12, c13, c14, c15, c16, c17, c18, c19, c20, c21, c22, c23, c24, c25, c26, c27, c29, c30, c32, c33, ...
# Found connecting edges between c1 and c33
# Merge score: 1.583181
# Better than: 1.469775
#
# Checking c2 with...
# c3, c4, c5, c6, c7, c8, c9, c10, c11, ...
# Found connecting edges between c2 and c11
# Merge score: 1.270592
# ..., c12, c13, c14, c15, c16, c17, c18, c19, ...
# Found connecting edges between c2 and c19
# Merge score: 0.117805
# ..., c20, c21, c22, c23, c24, c25, c26, ...
# Found connecting edges between c2 and c26
# Merge score: 1.691403
# Better than: 1.583181
#
# Checking c3 with...
# c4, c5, c6, c7, c8, c9, c10, c11, c12, c13, c14, c15, c16, c17, c18, c19, c20, c21, c22, c23, c24, c25, c26, c27, ...
# Found connecting edges between c3 and c27
# Merge score: 0.184644
#
# Checking c4 with...
# c5, c6, c7, c8, ...
# Found connecting edges between c4 and c8
# Merge score: 0.866522
# ..., c9, c10, c11, c12, c13, c14, c15, c16, c17, c18, c19, c20, c21, c22, ...
# Found connecting edges between c4 and c22
# Merge score: 0.892151
# ..., c23, c24, ...
# Found connecting edges between c4 and c24
# Merge score: 0.017291
# ..., c25, c26, c27, c29, c30, c32, c33, c34, c35, c36, c37, c38, ...
# Found connecting edges between c4 and c38
# Merge score: 0.574479
#
# Checking c5 with...
# c6, c7, c8, c9, ...
# Found connecting edges between c5 and c9
# Merge score: 0.735919
# ..., c10, ...
# Found connecting edges between c5 and c10
# Merge score: 0.739349
# ..., c11, c12, c13, c14, c15, c16, c17, ...
# Found connecting edges between c5 and c17
# Merge score: 0.694861
# ..., c18, ...
# Found connecting edges between c5 and c18
# Merge score: 0.523832
#
# Checking c6 with...
# c7, c8, c9, c10, c11, c12, c13, ...
# Found connecting edges between c6 and c13
# Merge score: 0.898897
# ..., c14, c15, c16, c17, c18, c19, c20, c21, c22, c23, ...
# Found connecting edges between c6 and c23
# Merge score: 0.394068
# ..., c24, c25, c26, c27, c29, c30, c32, c33, c34, c35, c36, ...
# Found connecting edges between c6 and c36
# Merge score: 1.227294
#
# Checking c7 with...
# c8, c9, c10, c11, c12, c13, c14, c15, c16, c17, c18, c19, c20, c21, c22, c23, c24, c25, c26, c27, c29, c30, c32, c33, c34, ...
# Found connecting edges between c7 and c34
# Merge score: 1.626234
#
# Checking c8 with...
# c9, c10, c11, c12, c13, c14, c15, c16, ...
# Found connecting edges between c8 and c16
# Merge score: 1.125431
# ..., c17, c18, c19, c20, c21, c22, c23, c24, ...
# Found connecting edges between c8 and c24
# Merge score: 0.546629
# ..., c25, c26, c27, c29, c30, c32, c33, c34, c35, c36, c37, c38, ...
# Found connecting edges between c8 and c38
# Merge score: 0.103706
#
# Checking c9 with...
# c10, c11, c12, c13, c14, c15, c16, c17, ...
# Found connecting edges between c9 and c17
# Merge score: 0.662020
# ..., c18, c19, c20, c21, c22, c23, c24, c25, c26, c27, c29, ...
# Found connecting edges between c9 and c29
# Merge score: 0.730529
#
# Checking c10 with...
# c11, c12, c13, c14, c15, c16, c17, c18, ...
# Found connecting edges between c10 and c18
# Merge score: 0.673215
# ..., c19, c20, c21, c22, c23, c24, c25, c26, c27, c29, c30, ...
# Found connecting edges between c10 and c30
# Merge score: 1.224740
#
# Checking c11 with...
# c12, c13, c14, c15, c16, ...
# Found connecting edges between c11 and c16
# Merge score: 0.007173
# ..., c17, c18, c19, ...
# Found connecting edges between c11 and c19
# Merge score: 0.531685
# ..., c20, c21, c22, c23, c24, c25, c26, ...
# Found connecting edges between c11 and c26
# Merge score: 0.050802
# ..., c27, c29, c30, c32, ...
# Found connecting edges between c11 and c32
# Merge score: 1.046928
#
# Checking c12 with...
# c13, c14, c15, c16, c17, c18, c19, c20, ...
# Found connecting edges between c12 and c20
# Merge score: 0.202955
# ..., c21, c22, c23, ...
# Found connecting edges between c12 and c23
# Merge score: 0.339124
# ..., c24, c25, c26, c27, c29, c30, c32, c33, ...
# Found connecting edges between c12 and c33
# Merge score: 1.528766
# ..., c34, c35, ...
# Found connecting edges between c12 and c35
# Merge score: 1.130192
#
# Checking c13 with...
# c14, c15, c16, c17, c18, c19, c20, c21, c22, c23, ...
# Found connecting edges between c13 and c23
# Merge score: 0.764793
#
# Checking c14 with...
# c15, c16, c17, c18, c19, c20, c21, c22, c23, c24, c25, c26, c27, ...
# Found connecting edges between c14 and c27
# Merge score: 1.133190
# ..., c29, c30, c32, c33, c34, c35, c36, c37, ...
# Found connecting edges between c14 and c37
# Merge score: 0.705070
#
# Checking c15 with...
# c16, c17, c18, c19, c20, c21, c22, c23, c24, c25, ...
# Found connecting edges between c15 and c25
# Merge score: 1.198138
#
# Checking c16 with...
# c17, c18, c19, c20, c21, c22, c23, c24, ...
# Found connecting edges between c16 and c24
# Merge score: 1.301812
# ..., c25, c26, c27, c29, c30, c32, ...
# Found connecting edges between c16 and c32
# Merge score: 0.281282
#
# Checking c17 with...
# c18, ...
# Found connecting edges between c17 and c18
# Merge score: 0.266469
# ..., c19, c20, c21, ...
# Found connecting edges between c17 and c21
# Merge score: 0.471926
# ..., c22, c23, c24, c25, c26, c27, c29, ...
# Found connecting edges between c17 and c29
# Merge score: 1.705780
# Better than: 1.691403
#
# Checking c18 with...
# c19, c20, c21, ...
# Found connecting edges between c18 and c21
# Merge score: 0.025581
# ..., c22, c23, c24, c25, c26, c27, ...
# Found connecting edges between c18 and c27
# Merge score: 0.019258
# ..., c29, c30, ...
# Found connecting edges between c18 and c30
# Merge score: 1.531350
#
# Checking c19 with...
# c20, c21, c22, c23, c24, c25, c26, ...
# Found connecting edges between c19 and c26
# Merge score: 1.052351
# ..., c27, c29, c30, c32, ...
# Found connecting edges between c19 and c32
# Merge score: 1.142789
#
# Checking c20 with...
# c21, c22, c23, ...
# Found connecting edges between c20 and c23
# Merge score: 0.152687
# ..., c24, c25, c26, c27, c29, c30, c32, c33, c34, c35, ...
# Found connecting edges between c20 and c35
# Merge score: 1.302509
# ..., c36, ...
# Found connecting edges between c20 and c36
# Merge score: 1.520098
#
# Checking c21 with...
# c22, c23, c24, c25, c26, c27, c29, ...
# Found connecting edges between c21 and c29
# Merge score: 1.016531
# ..., c30, c32, c33, c34, c35, c36, c37, ...
# Found connecting edges between c21 and c37
# Merge score: 1.232921
#
# Checking c22 with...
# c23, c24, c25, c26, c27, c29, c30, c32, c33, c34, c35, c36, c37, c38, ...
# Found connecting edges between c22 and c38
# Merge score: 1.029239
#
# Checking c23 with...
# c24, c25, c26, c27, c29, c30, c32, c33, ...
# Found connecting edges between c23 and c33
# Merge score: 0.987662
# ..., c34, c35, c36, ...
# Found connecting edges between c23 and c36
# Merge score: 1.334870
#
# Checking c24 with...
# c25, c26, c27, c29, c30, c32, c33, c34, c35, c36, c37, c38, ...
# Found connecting edges between c24 and c38
# Merge score: 0.754396
#
# Checking c25 with...
#
# Checking c26 with...
#
# Checking c27 with...
# c29, c30, ...
# Found connecting edges between c27 and c30
# Merge score: 1.493623
#
# Checking c29 with...
# c30, c32, c33, c34, c35, c36, c37, ...
# Found connecting edges between c29 and c37
# Merge score: 0.288049
#
# Checking c30 with...
#
# Checking c32 with...
#
# Checking c33 with...
#
# Checking c34 with...
#
# Checking c35 with...
#
# Checking c36 with...
#
# Checking c37 with...
# Merging c17 and c29
#  12%|█▏        | 4/33 [00:07<00:50,  1.76s/it]
# Checking c0 with...
# c1, c2, c3, c4, c5, ...
# Found connecting edges between c0 and c5
# Merge score: 0.011645
# Better than: 0.000000
# ..., c6, c7, c8, c9, c10, c11, c12, c13, c14, ...
# Found connecting edges between c0 and c14
# Merge score: 0.721901
# Better than: 0.011645
# ..., c15, c16, c17, ...
# Found connecting edges between c0 and c17
# Merge score: 0.108389
# ..., c18, ...
# Found connecting edges between c0 and c18
# Merge score: 1.469775
# Better than: 0.721901
# ..., c19, c20, c21, ...
# Found connecting edges between c0 and c21
# Merge score: 1.363032
# ..., c22, c23, c24, c25, c26, c27, ...
# Found connecting edges between c0 and c27
# Merge score: 0.545907
# ..., c30, ...
# Found connecting edges between c0 and c30
# Merge score: 0.202118
# ..., c32, c33, c34, c35, c36, c37, ...
# Found connecting edges between c0 and c37
# Merge score: 0.858185
#
# Checking c1 with...
# c2, c3, c4, c5, c6, c7, c8, c9, c10, c11, c12, c13, c14, c15, c16, c17, c18, c19, c20, c21, c22, c23, c24, c25, c26, c27, c30, c32, c33, ...
# Found connecting edges between c1 and c33
# Merge score: 1.583181
# Better than: 1.469775
#
# Checking c2 with...
# c3, c4, c5, c6, c7, c8, c9, c10, c11, ...
# Found connecting edges between c2 and c11
# Merge score: 1.270592
# ..., c12, c13, c14, c15, c16, c17, c18, c19, ...
# Found connecting edges between c2 and c19
# Merge score: 0.117805
# ..., c20, c21, c22, c23, c24, c25, c26, ...
# Found connecting edges between c2 and c26
# Merge score: 1.691403
# Better than: 1.583181
#
# Checking c3 with...
# c4, c5, c6, c7, c8, c9, c10, c11, c12, c13, c14, c15, c16, c17, c18, c19, c20, c21, c22, c23, c24, c25, c26, c27, ...
# Found connecting edges between c3 and c27
# Merge score: 0.184644
#
# Checking c4 with...
# c5, c6, c7, c8, ...
# Found connecting edges between c4 and c8
# Merge score: 0.866522
# ..., c9, c10, c11, c12, c13, c14, c15, c16, c17, c18, c19, c20, c21, c22, ...
# Found connecting edges between c4 and c22
# Merge score: 0.892151
# ..., c23, c24, ...
# Found connecting edges between c4 and c24
# Merge score: 0.017291
# ..., c25, c26, c27, c30, c32, c33, c34, c35, c36, c37, c38, ...
# Found connecting edges between c4 and c38
# Merge score: 0.574479
#
# Checking c5 with...
# c6, c7, c8, c9, ...
# Found connecting edges between c5 and c9
# Merge score: 0.735919
# ..., c10, ...
# Found connecting edges between c5 and c10
# Merge score: 0.739349
# ..., c11, c12, c13, c14, c15, c16, c17, ...
# Found connecting edges between c5 and c17
# Merge score: 0.591639
# ..., c18, ...
# Found connecting edges between c5 and c18
# Merge score: 0.523832
#
# Checking c6 with...
# c7, c8, c9, c10, c11, c12, c13, ...
# Found connecting edges between c6 and c13
# Merge score: 0.898897
# ..., c14, c15, c16, c17, c18, c19, c20, c21, c22, c23, ...
# Found connecting edges between c6 and c23
# Merge score: 0.394068
# ..., c24, c25, c26, c27, c30, c32, c33, c34, c35, c36, ...
# Found connecting edges between c6 and c36
# Merge score: 1.227294
#
# Checking c7 with...
# c8, c9, c10, c11, c12, c13, c14, c15, c16, c17, c18, c19, c20, c21, c22, c23, c24, c25, c26, c27, c30, c32, c33, c34, ...
# Found connecting edges between c7 and c34
# Merge score: 1.626234
#
# Checking c8 with...
# c9, c10, c11, c12, c13, c14, c15, c16, ...
# Found connecting edges between c8 and c16
# Merge score: 1.125431
# ..., c17, c18, c19, c20, c21, c22, c23, c24, ...
# Found connecting edges between c8 and c24
# Merge score: 0.546629
# ..., c25, c26, c27, c30, c32, c33, c34, c35, c36, c37, c38, ...
# Found connecting edges between c8 and c38
# Merge score: 0.103706
#
# Checking c9 with...
# c10, c11, c12, c13, c14, c15, c16, c17, ...
# Found connecting edges between c9 and c17
# Merge score: 1.047100
#
# Checking c10 with...
# c11, c12, c13, c14, c15, c16, c17, c18, ...
# Found connecting edges between c10 and c18
# Merge score: 0.673215
# ..., c19, c20, c21, c22, c23, c24, c25, c26, c27, c30, ...
# Found connecting edges between c10 and c30
# Merge score: 1.224740
#
# Checking c11 with...
# c12, c13, c14, c15, c16, ...
# Found connecting edges between c11 and c16
# Merge score: 0.007173
# ..., c17, c18, c19, ...
# Found connecting edges between c11 and c19
# Merge score: 0.531685
# ..., c20, c21, c22, c23, c24, c25, c26, ...
# Found connecting edges between c11 and c26
# Merge score: 0.050802
# ..., c27, c30, c32, ...
# Found connecting edges between c11 and c32
# Merge score: 1.046928
#
# Checking c12 with...
# c13, c14, c15, c16, c17, c18, c19, c20, ...
# Found connecting edges between c12 and c20
# Merge score: 0.202955
# ..., c21, c22, c23, ...
# Found connecting edges between c12 and c23
# Merge score: 0.339124
# ..., c24, c25, c26, c27, c30, c32, c33, ...
# Found connecting edges between c12 and c33
# Merge score: 1.528766
# ..., c34, c35, ...
# Found connecting edges between c12 and c35
# Merge score: 1.130192
#
# Checking c13 with...
# c14, c15, c16, c17, c18, c19, c20, c21, c22, c23, ...
# Found connecting edges between c13 and c23
# Merge score: 0.764793
#
# Checking c14 with...
# c15, c16, c17, c18, c19, c20, c21, c22, c23, c24, c25, c26, c27, ...
# Found connecting edges between c14 and c27
# Merge score: 1.133190
# ..., c30, c32, c33, c34, c35, c36, c37, ...
# Found connecting edges between c14 and c37
# Merge score: 0.705070
#
# Checking c15 with...
# c16, c17, c18, c19, c20, c21, c22, c23, c24, c25, ...
# Found connecting edges between c15 and c25
# Merge score: 1.198138
#
# Checking c16 with...
# c17, c18, c19, c20, c21, c22, c23, c24, ...
# Found connecting edges between c16 and c24
# Merge score: 1.301812
# ..., c25, c26, c27, c30, c32, ...
# Found connecting edges between c16 and c32
# Merge score: 0.281282
#
# Checking c17 with...
# c18, ...
# Found connecting edges between c17 and c18
# Merge score: 0.203830
# ..., c19, c20, c21, ...
# Found connecting edges between c17 and c21
# Merge score: 1.115424
# ..., c22, c23, c24, c25, c26, c27, c30, c32, c33, c34, c35, c36, c37, ...
# Found connecting edges between c17 and c37
# Merge score: 0.206005
#
# Checking c18 with...
# c19, c20, c21, ...
# Found connecting edges between c18 and c21
# Merge score: 0.025581
# ..., c22, c23, c24, c25, c26, c27, ...
# Found connecting edges between c18 and c27
# Merge score: 0.019258
# ..., c30, ...
# Found connecting edges between c18 and c30
# Merge score: 1.531350
#
# Checking c19 with...
# c20, c21, c22, c23, c24, c25, c26, ...
# Found connecting edges between c19 and c26
# Merge score: 1.052351
# ..., c27, c30, c32, ...
# Found connecting edges between c19 and c32
# Merge score: 1.142789
#
# Checking c20 with...
# c21, c22, c23, ...
# Found connecting edges between c20 and c23
# Merge score: 0.152687
# ..., c24, c25, c26, c27, c30, c32, c33, c34, c35, ...
# Found connecting edges between c20 and c35
# Merge score: 1.302509
# ..., c36, ...
# Found connecting edges between c20 and c36
# Merge score: 1.520098
#
# Checking c21 with...
# c22, c23, c24, c25, c26, c27, c30, c32, c33, c34, c35, c36, c37, ...
# Found connecting edges between c21 and c37
# Merge score: 1.232921
#
# Checking c22 with...
# c23, c24, c25, c26, c27, c30, c32, c33, c34, c35, c36, c37, c38, ...
# Found connecting edges between c22 and c38
# Merge score: 1.029239
#
# Checking c23 with...
# c24, c25, c26, c27, c30, c32, c33, ...
# Found connecting edges between c23 and c33
# Merge score: 0.987662
# ..., c34, c35, c36, ...
# Found connecting edges between c23 and c36
# Merge score: 1.334870
#
# Checking c24 with...
# c25, c26, c27, c30, c32, c33, c34, c35, c36, c37, c38, ...
# Found connecting edges between c24 and c38
# Merge score: 0.754396
#
# Checking c25 with...
#
# Checking c26 with...
#
# Checking c27 with...
# c30, ...
# Found connecting edges between c27 and c30
# Merge score: 1.493623
#
# Checking c30 with...
#
# Checking c32 with...
#
# Checking c33 with...
#
# Checking c34 with...
#
# Checking c35 with...
#
# Checking c36 with...
#
# Checking c37 with...
# Merging c2 and c26
#  15%|█▌        | 5/33 [00:09<00:50,  1.81s/it]
# Checking c0 with...
# c1, c2, c3, c4, c5, ...
# Found connecting edges between c0 and c5
# Merge score: 0.011645
# Better than: 0.000000
# ..., c6, c7, c8, c9, c10, c11, c12, c13, c14, ...
# Found connecting edges between c0 and c14
# Merge score: 0.721901
# Better than: 0.011645
# ..., c15, c16, c17, ...
# Found connecting edges between c0 and c17
# Merge score: 0.108389
# ..., c18, ...
# Found connecting edges between c0 and c18
# Merge score: 1.469775
# Better than: 0.721901
# ..., c19, c20, c21, ...
# Found connecting edges between c0 and c21
# Merge score: 1.363032
# ..., c22, c23, c24, c25, c27, ...
# Found connecting edges between c0 and c27
# Merge score: 0.545907
# ..., c30, ...
# Found connecting edges between c0 and c30
# Merge score: 0.202118
# ..., c32, c33, c34, c35, c36, c37, ...
# Found connecting edges between c0 and c37
# Merge score: 0.858185
#
# Checking c1 with...
# c2, c3, c4, c5, c6, c7, c8, c9, c10, c11, c12, c13, c14, c15, c16, c17, c18, c19, c20, c21, c22, c23, c24, c25, c27, c30, c32, c33, ...
# Found connecting edges between c1 and c33
# Merge score: 1.583181
# Better than: 1.469775
#
# Checking c2 with...
# c3, c4, c5, c6, c7, c8, c9, c10, c11, ...
# Found connecting edges between c2 and c11
# Merge score: 1.063259
# ..., c12, c13, c14, c15, c16, c17, c18, c19, ...
# Found connecting edges between c2 and c19
# Merge score: 0.826373
#
# Checking c3 with...
# c4, c5, c6, c7, c8, c9, c10, c11, c12, c13, c14, c15, c16, c17, c18, c19, c20, c21, c22, c23, c24, c25, c27, ...
# Found connecting edges between c3 and c27
# Merge score: 0.184644
#
# Checking c4 with...
# c5, c6, c7, c8, ...
# Found connecting edges between c4 and c8
# Merge score: 0.866522
# ..., c9, c10, c11, c12, c13, c14, c15, c16, c17, c18, c19, c20, c21, c22, ...
# Found connecting edges between c4 and c22
# Merge score: 0.892151
# ..., c23, c24, ...
# Found connecting edges between c4 and c24
# Merge score: 0.017291
# ..., c25, c27, c30, c32, c33, c34, c35, c36, c37, c38, ...
# Found connecting edges between c4 and c38
# Merge score: 0.574479
#
# Checking c5 with...
# c6, c7, c8, c9, ...
# Found connecting edges between c5 and c9
# Merge score: 0.735919
# ..., c10, ...
# Found connecting edges between c5 and c10
# Merge score: 0.739349
# ..., c11, c12, c13, c14, c15, c16, c17, ...
# Found connecting edges between c5 and c17
# Merge score: 0.591639
# ..., c18, ...
# Found connecting edges between c5 and c18
# Merge score: 0.523832
#
# Checking c6 with...
# c7, c8, c9, c10, c11, c12, c13, ...
# Found connecting edges between c6 and c13
# Merge score: 0.898897
# ..., c14, c15, c16, c17, c18, c19, c20, c21, c22, c23, ...
# Found connecting edges between c6 and c23
# Merge score: 0.394068
# ..., c24, c25, c27, c30, c32, c33, c34, c35, c36, ...
# Found connecting edges between c6 and c36
# Merge score: 1.227294
#
# Checking c7 with...
# c8, c9, c10, c11, c12, c13, c14, c15, c16, c17, c18, c19, c20, c21, c22, c23, c24, c25, c27, c30, c32, c33, c34, ...
# Found connecting edges between c7 and c34
# Merge score: 1.626234
# Better than: 1.583181
#
# Checking c8 with...
# c9, c10, c11, c12, c13, c14, c15, c16, ...
# Found connecting edges between c8 and c16
# Merge score: 1.125431
# ..., c17, c18, c19, c20, c21, c22, c23, c24, ...
# Found connecting edges between c8 and c24
# Merge score: 0.546629
# ..., c25, c27, c30, c32, c33, c34, c35, c36, c37, c38, ...
# Found connecting edges between c8 and c38
# Merge score: 0.103706
#
# Checking c9 with...
# c10, c11, c12, c13, c14, c15, c16, c17, ...
# Found connecting edges between c9 and c17
# Merge score: 1.047100
#
# Checking c10 with...
# c11, c12, c13, c14, c15, c16, c17, c18, ...
# Found connecting edges between c10 and c18
# Merge score: 0.673215
# ..., c19, c20, c21, c22, c23, c24, c25, c27, c30, ...
# Found connecting edges between c10 and c30
# Merge score: 1.224740
#
# Checking c11 with...
# c12, c13, c14, c15, c16, ...
# Found connecting edges between c11 and c16
# Merge score: 0.007173
# ..., c17, c18, c19, ...
# Found connecting edges between c11 and c19
# Merge score: 0.531685
# ..., c20, c21, c22, c23, c24, c25, c27, c30, c32, ...
# Found connecting edges between c11 and c32
# Merge score: 1.046928
#
# Checking c12 with...
# c13, c14, c15, c16, c17, c18, c19, c20, ...
# Found connecting edges between c12 and c20
# Merge score: 0.202955
# ..., c21, c22, c23, ...
# Found connecting edges between c12 and c23
# Merge score: 0.339124
# ..., c24, c25, c27, c30, c32, c33, ...
# Found connecting edges between c12 and c33
# Merge score: 1.528766
# ..., c34, c35, ...
# Found connecting edges between c12 and c35
# Merge score: 1.130192
#
# Checking c13 with...
# c14, c15, c16, c17, c18, c19, c20, c21, c22, c23, ...
# Found connecting edges between c13 and c23
# Merge score: 0.764793
#
# Checking c14 with...
# c15, c16, c17, c18, c19, c20, c21, c22, c23, c24, c25, c27, ...
# Found connecting edges between c14 and c27
# Merge score: 1.133190
# ..., c30, c32, c33, c34, c35, c36, c37, ...
# Found connecting edges between c14 and c37
# Merge score: 0.705070
#
# Checking c15 with...
# c16, c17, c18, c19, c20, c21, c22, c23, c24, c25, ...
# Found connecting edges between c15 and c25
# Merge score: 1.198138
#
# Checking c16 with...
# c17, c18, c19, c20, c21, c22, c23, c24, ...
# Found connecting edges between c16 and c24
# Merge score: 1.301812
# ..., c25, c27, c30, c32, ...
# Found connecting edges between c16 and c32
# Merge score: 0.281282
#
# Checking c17 with...
# c18, ...
# Found connecting edges between c17 and c18
# Merge score: 0.203830
# ..., c19, c20, c21, ...
# Found connecting edges between c17 and c21
# Merge score: 1.115424
# ..., c22, c23, c24, c25, c27, c30, c32, c33, c34, c35, c36, c37, ...
# Found connecting edges between c17 and c37
# Merge score: 0.206005
#
# Checking c18 with...
# c19, c20, c21, ...
# Found connecting edges between c18 and c21
# Merge score: 0.025581
# ..., c22, c23, c24, c25, c27, ...
# Found connecting edges between c18 and c27
# Merge score: 0.019258
# ..., c30, ...
# Found connecting edges between c18 and c30
# Merge score: 1.531350
#
# Checking c19 with...
# c20, c21, c22, c23, c24, c25, c27, c30, c32, ...
# Found connecting edges between c19 and c32
# Merge score: 1.142789
#
# Checking c20 with...
# c21, c22, c23, ...
# Found connecting edges between c20 and c23
# Merge score: 0.152687
# ..., c24, c25, c27, c30, c32, c33, c34, c35, ...
# Found connecting edges between c20 and c35
# Merge score: 1.302509
# ..., c36, ...
# Found connecting edges between c20 and c36
# Merge score: 1.520098
#
# Checking c21 with...
# c22, c23, c24, c25, c27, c30, c32, c33, c34, c35, c36, c37, ...
# Found connecting edges between c21 and c37
# Merge score: 1.232921
#
# Checking c22 with...
# c23, c24, c25, c27, c30, c32, c33, c34, c35, c36, c37, c38, ...
# Found connecting edges between c22 and c38
# Merge score: 1.029239
#
# Checking c23 with...
# c24, c25, c27, c30, c32, c33, ...
# Found connecting edges between c23 and c33
# Merge score: 0.987662
# ..., c34, c35, c36, ...
# Found connecting edges between c23 and c36
# Merge score: 1.334870
#
# ...
# Found connecting edges between c14 and c27
# Merge score: 1.133190
#
# Checking c15 with...
#
# Checking c17 with...
#
# Checking c22 with...
# c27, c38, ...
# Found connecting edges between c22 and c38
# Merge score: 1.029239
#
# Checking c27 with...
# Merging c2 and c11
#  67%|██████▋   | 22/33 [00:34<00:14,  1.36s/it]
# Checking c0 with...
# c1, c2, c3, c4, c5, ...
# Found connecting edges between c0 and c5
# Merge score: 0.008441
# Better than: 0.000000
# ..., c6, c7, c8, c9, c10, ...
# Found connecting edges between c0 and c10
# Merge score: 0.757753
# Better than: 0.008441
# ..., c13, c14, ...
# Found connecting edges between c0 and c14
# Merge score: 0.775009
# Better than: 0.757753
# ..., c15, c17, ...
# Found connecting edges between c0 and c17
# Merge score: 0.910192
# Better than: 0.775009
# ..., c22, c27, ...
# Found connecting edges between c0 and c27
# Merge score: 0.336589
#
# Checking c1 with...
# c2, c3, c4, c5, c6, ...
# Found connecting edges between c1 and c6
# Merge score: 0.693223
# ..., c7, c8, c9, c10, c13, ...
# Found connecting edges between c1 and c13
# Merge score: 0.460645
#
# Checking c2 with...
# c3, c4, c5, c6, c7, c8, ...
# Found connecting edges between c2 and c8
# Merge score: 0.160684
#
# Checking c3 with...
# c4, c5, c6, c7, c8, c9, c10, c13, c14, c15, c17, c22, c27, ...
# Found connecting edges between c3 and c27
# Merge score: 0.184644
#
# Checking c4 with...
# c5, c6, c7, c8, ...
# Found connecting edges between c4 and c8
# Merge score: 0.665754
# ..., c9, c10, c13, c14, c15, c17, c22, ...
# Found connecting edges between c4 and c22
# Merge score: 0.892151
# ..., c27, c38, ...
# Found connecting edges between c4 and c38
# Merge score: 0.574479
#
# Checking c5 with...
# c6, c7, c8, c9, ...
# Found connecting edges between c5 and c9
# Merge score: 0.735919
# ..., c10, ...
# Found connecting edges between c5 and c10
# Merge score: 0.997005
# Better than: 0.910192
# ..., c13, c14, c15, c17, ...
# Found connecting edges between c5 and c17
# Merge score: 0.591639
#
# Checking c6 with...
# c7, c8, c9, c10, c13, ...
# Found connecting edges between c6 and c13
# Merge score: 0.898897
#
# Checking c7 with...
#
# Checking c8 with...
# c9, c10, c13, c14, c15, c17, c22, c27, c38, ...
# Found connecting edges between c8 and c38
# Merge score: 0.512496
#
# Checking c9 with...
# c10, c13, c14, c15, c17, ...
# Found connecting edges between c9 and c17
# Merge score: 1.047100
# Better than: 0.997005
#
# Checking c10 with...
# c13, c14, c15, c17, ...
# Found connecting edges between c10 and c17
# Merge score: 0.130609
# ..., c22, c27, ...
# Found connecting edges between c10 and c27
# Merge score: 0.982058
#
# Checking c13 with...
#
# Checking c14 with...
# c15, c17, c22, c27, ...
# Found connecting edges between c14 and c27
# Merge score: 1.133190
# Better than: 1.047100
#
# Checking c15 with...
#
# Checking c17 with...
#
# Checking c22 with...
# c27, c38, ...
# Found connecting edges between c22 and c38
# Merge score: 1.029239
#
# Checking c27 with...
# Merging c14 and c27
#  70%|██████▉   | 23/33 [00:36<00:14,  1.43s/it]
# Checking c0 with...
# c1, c2, c3, c4, c5, ...
# Found connecting edges between c0 and c5
# Merge score: 0.008441
# Better than: 0.000000
# ..., c6, c7, c8, c9, c10, ...
# Found connecting edges between c0 and c10
# Merge score: 0.757753
# Better than: 0.008441
# ..., c13, c14, ...
# Found connecting edges between c0 and c14
# Merge score: 1.124130
# Better than: 0.757753
# ..., c15, c17, ...
# Found connecting edges between c0 and c17
# Merge score: 0.910192
#
# Checking c1 with...
# c2, c3, c4, c5, c6, ...
# Found connecting edges between c1 and c6
# Merge score: 0.693223
# ..., c7, c8, c9, c10, c13, ...
# Found connecting edges between c1 and c13
# Merge score: 0.460645
#
# Checking c2 with...
# c3, c4, c5, c6, c7, c8, ...
# Found connecting edges between c2 and c8
# Merge score: 0.160684
#
# Checking c3 with...
# c4, c5, c6, c7, c8, c9, c10, c13, c14, ...
# Found connecting edges between c3 and c14
# Merge score: 0.180762
#
# Checking c4 with...
# c5, c6, c7, c8, ...
# Found connecting edges between c4 and c8
# Merge score: 0.665754
# ..., c9, c10, c13, c14, c15, c17, c22, ...
# Found connecting edges between c4 and c22
# Merge score: 0.892151
# ..., c38, ...
# Found connecting edges between c4 and c38
# Merge score: 0.574479
#
# Checking c5 with...
# c6, c7, c8, c9, ...
# Found connecting edges between c5 and c9
# Merge score: 0.735919
# ..., c10, ...
# Found connecting edges between c5 and c10
# Merge score: 0.997005
# ..., c13, c14, c15, c17, ...
# Found connecting edges between c5 and c17
# Merge score: 0.591639
#
# Checking c6 with...
# c7, c8, c9, c10, c13, ...
# Found connecting edges between c6 and c13
# Merge score: 0.898897
#
# Checking c7 with...
#
# Checking c8 with...
# c9, c10, c13, c14, c15, c17, c22, c38, ...
# Found connecting edges between c8 and c38
# Merge score: 0.512496
#
# Checking c9 with...
# c10, c13, c14, c15, c17, ...
# Found connecting edges between c9 and c17
# Merge score: 1.047100
#
# Checking c10 with...
# c13, c14, ...
# Found connecting edges between c10 and c14
# Merge score: 0.985759
# ..., c15, c17, ...
# Found connecting edges between c10 and c17
# Merge score: 0.130609
#
# Checking c13 with...
#
# Checking c14 with...
#
# Checking c15 with...
#
# Checking c17 with...
#
# Checking c22 with...
# c38, ...
# Found connecting edges between c22 and c38
# Merge score: 1.029239
# Merging c0 and c14
#  73%|███████▎  | 24/33 [00:37<00:11,  1.33s/it]
# Checking c0 with...
# c1, c2, c3, ...
# Found connecting edges between c0 and c3
# Merge score: 0.141626
# Better than: 0.000000
# ..., c4, c5, ...
# Found connecting edges between c0 and c5
# Merge score: 0.009823
# ..., c6, c7, c8, c9, c10, ...
# Found connecting edges between c0 and c10
# Merge score: 1.614772
# Better than: 0.141626
# ..., c13, c15, c17, ...
# Found connecting edges between c0 and c17
# Merge score: 1.046150
#
# Checking c1 with...
# c2, c3, c4, c5, c6, ...
# Found connecting edges between c1 and c6
# Merge score: 0.693223
# ..., c7, c8, c9, c10, c13, ...
# Found connecting edges between c1 and c13
# Merge score: 0.460645
#
# Checking c2 with...
# c3, c4, c5, c6, c7, c8, ...
# Found connecting edges between c2 and c8
# Merge score: 0.160684
#
# Checking c3 with...
#
# Checking c4 with...
# c5, c6, c7, c8, ...
# Found connecting edges between c4 and c8
# Merge score: 0.665754
# ..., c9, c10, c13, c15, c17, c22, ...
# Found connecting edges between c4 and c22
# Merge score: 0.892151
# ..., c38, ...
# Found connecting edges between c4 and c38
# Merge score: 0.574479
#
# Checking c5 with...
# c6, c7, c8, c9, ...
# Found connecting edges between c5 and c9
# Merge score: 0.735919
# ..., c10, ...
# Found connecting edges between c5 and c10
# Merge score: 0.997005
# ..., c13, c15, c17, ...
# Found connecting edges between c5 and c17
# Merge score: 0.591639
#
# Checking c6 with...
# c7, c8, c9, c10, c13, ...
# Found connecting edges between c6 and c13
# Merge score: 0.898897
#
# Checking c7 with...
#
# Checking c8 with...
# c9, c10, c13, c15, c17, c22, c38, ...
# Found connecting edges between c8 and c38
# Merge score: 0.512496
#
# Checking c9 with...
# c10, c13, c15, c17, ...
# Found connecting edges between c9 and c17
# Merge score: 1.047100
#
# Checking c10 with...
# c13, c15, c17, ...
# Found connecting edges between c10 and c17
# Merge score: 0.130609
#
# Checking c13 with...
#
# Checking c15 with...
#
# Checking c17 with...
#
# Checking c22 with...
# c38, ...
# Found connecting edges between c22 and c38
# Merge score: 1.029239
# Merging c0 and c10
#  76%|███████▌  | 25/33 [00:38<00:10,  1.27s/it]
# Checking c0 with...
# c1, c2, c3, ...
# Found connecting edges between c0 and c3
# Merge score: 0.099116
# Better than: 0.000000
# ..., c4, c5, ...
# Found connecting edges between c0 and c5
# Merge score: 0.732513
# Better than: 0.099116
# ..., c6, c7, c8, c9, c13, c15, c17, ...
# Found connecting edges between c0 and c17
# Merge score: 0.800476
# Better than: 0.732513
#
# Checking c1 with...
# c2, c3, c4, c5, c6, ...
# Found connecting edges between c1 and c6
# Merge score: 0.693223
# ..., c7, c8, c9, c13, ...
# Found connecting edges between c1 and c13
# Merge score: 0.460645
#
# Checking c2 with...
# c3, c4, c5, c6, c7, c8, ...
# Found connecting edges between c2 and c8
# Merge score: 0.160684
#
# Checking c3 with...
#
# Checking c4 with...
# c5, c6, c7, c8, ...
# Found connecting edges between c4 and c8
# Merge score: 0.665754
# ..., c9, c13, c15, c17, c22, ...
# Found connecting edges between c4 and c22
# Merge score: 0.892151
# Better than: 0.800476
# ..., c38, ...
# Found connecting edges between c4 and c38
# Merge score: 0.574479
#
# Checking c5 with...
# c6, c7, c8, c9, ...
# Found connecting edges between c5 and c9
# Merge score: 0.735919
# ..., c13, c15, c17, ...
# Found connecting edges between c5 and c17
# Merge score: 0.591639
#
# Checking c6 with...
# c7, c8, c9, c13, ...
# Found connecting edges between c6 and c13
# Merge score: 0.898897
# Better than: 0.892151
#
# Checking c7 with...
#
# Checking c8 with...
# c9, c13, c15, c17, c22, c38, ...
# Found connecting edges between c8 and c38
# Merge score: 0.512496
#
# Checking c9 with...
# c13, c15, c17, ...
# Found connecting edges between c9 and c17
# Merge score: 1.047100
# Better than: 0.898897
#
# Checking c13 with...
#
# Checking c15 with...
#
# Checking c17 with...
#
# Checking c22 with...
# c38, ...
# Found connecting edges between c22 and c38
# Merge score: 1.029239
# Merging c9 and c17
#  79%|███████▉  | 26/33 [00:39<00:08,  1.19s/it]
# Checking c0 with...
# c1, c2, c3, ...
# Found connecting edges between c0 and c3
# Merge score: 0.099116
# Better than: 0.000000
# ..., c4, c5, ...
# Found connecting edges between c0 and c5
# Merge score: 0.732513
# Better than: 0.099116
# ..., c6, c7, c8, c9, ...
# Found connecting edges between c0 and c9
# Merge score: 0.792886
# Better than: 0.732513
#
# Checking c1 with...
# c2, c3, c4, c5, c6, ...
# Found connecting edges between c1 and c6
# Merge score: 0.693223
# ..., c7, c8, c9, c13, ...
# Found connecting edges between c1 and c13
# Merge score: 0.460645
#
# Checking c2 with...
# c3, c4, c5, c6, c7, c8, ...
# Found connecting edges between c2 and c8
# Merge score: 0.160684
#
# Checking c3 with...
#
# Checking c4 with...
# c5, c6, c7, c8, ...
# Found connecting edges between c4 and c8
# Merge score: 0.665754
# ..., c9, c13, c15, c22, ...
# Found connecting edges between c4 and c22
# Merge score: 0.892151
# Better than: 0.792886
# ..., c38, ...
# Found connecting edges between c4 and c38
# Merge score: 0.574479
#
# Checking c5 with...
# c6, c7, c8, c9, ...
# Found connecting edges between c5 and c9
# Merge score: 1.340029
# Better than: 0.892151
#
# Checking c6 with...
# c7, c8, c9, c13, ...
# Found connecting edges between c6 and c13
# Merge score: 0.898897
#
# Checking c7 with...
#
# Checking c8 with...
# c9, c13, c15, c22, c38, ...
# Found connecting edges between c8 and c38
# Merge score: 0.512496
#
# Checking c9 with...
#
# Checking c13 with...
#
# Checking c15 with...
#
# Checking c22 with...
# c38, ...
# Found connecting edges between c22 and c38
# Merge score: 1.029239
# Merging c5 and c9
#  82%|████████▏ | 27/33 [00:40<00:06,  1.14s/it]
# Checking c0 with...
# c1, c2, c3, ...
# Found connecting edges between c0 and c3
# Merge score: 0.099116
# Better than: 0.000000
# ..., c4, c5, ...
# Found connecting edges between c0 and c5
# Merge score: 1.383033
# Better than: 0.099116
#
# Checking c1 with...
# c2, c3, c4, c5, c6, ...
# Found connecting edges between c1 and c6
# Merge score: 0.693223
# ..., c7, c8, c13, ...
# Found connecting edges between c1 and c13
# Merge score: 0.460645
#
# Checking c2 with...
# c3, c4, c5, c6, c7, c8, ...
# Found connecting edges between c2 and c8
# Merge score: 0.160684
#
# Checking c3 with...
#
# Checking c4 with...
# c5, c6, c7, c8, ...
# Found connecting edges between c4 and c8
# Merge score: 0.665754
# ..., c13, c15, c22, ...
# Found connecting edges between c4 and c22
# Merge score: 0.892151
# ..., c38, ...
# Found connecting edges between c4 and c38
# Merge score: 0.574479
#
# Checking c5 with...
#
# Checking c6 with...
# c7, c8, c13, ...
# Found connecting edges between c6 and c13
# Merge score: 0.898897
#
# Checking c7 with...
#
# Checking c8 with...
# c13, c15, c22, c38, ...
# Found connecting edges between c8 and c38
# Merge score: 0.512496
#
# Checking c13 with...
#
# Checking c15 with...
#
# Checking c22 with...
# c38, ...
# Found connecting edges between c22 and c38
# Merge score: 1.029239
# Merging c0 and c5
#  85%|████████▍ | 28/33 [00:41<00:05,  1.10s/it]
# Checking c0 with...
# c1, c2, c3, ...
# Found connecting edges between c0 and c3
# Merge score: 0.087269
# Better than: 0.000000
#
# Checking c1 with...
# c2, c3, c4, c6, ...
# Found connecting edges between c1 and c6
# Merge score: 0.693223
# Better than: 0.087269
# ..., c7, c8, c13, ...
# Found connecting edges between c1 and c13
# Merge score: 0.460645
#
# Checking c2 with...
# c3, c4, c6, c7, c8, ...
# Found connecting edges between c2 and c8
# Merge score: 0.160684
#
# Checking c3 with...
#
# Checking c4 with...
# c6, c7, c8, ...
# Found connecting edges between c4 and c8
# Merge score: 0.665754
# ..., c13, c15, c22, ...
# Found connecting edges between c4 and c22
# Merge score: 0.892151
# Better than: 0.693223
# ..., c38, ...
# Found connecting edges between c4 and c38
# Merge score: 0.574479
#
# Checking c6 with...
# c7, c8, c13, ...
# Found connecting edges between c6 and c13
# Merge score: 0.898897
# Better than: 0.892151
#
# Checking c7 with...
#
# Checking c8 with...
# c13, c15, c22, c38, ...
# Found connecting edges between c8 and c38
# Merge score: 0.512496
#
# Checking c13 with...
#
# Checking c15 with...
#
# Checking c22 with...
# c38, ...
# Found connecting edges between c22 and c38
# Merge score: 1.029239
# Better than: 0.898897
# Merging c22 and c38
#  88%|████████▊ | 29/33 [00:42<00:04,  1.03s/it]
# Checking c0 with...
# c1, c2, c3, ...
# Found connecting edges between c0 and c3
# Merge score: 0.087269
# Better than: 0.000000
#
# Checking c1 with...
# c2, c3, c4, c6, ...
# Found connecting edges between c1 and c6
# Merge score: 0.693223
# Better than: 0.087269
# ..., c7, c8, c13, ...
# Found connecting edges between c1 and c13
# Merge score: 0.460645
#
# Checking c2 with...
# c3, c4, c6, c7, c8, ...
# Found connecting edges between c2 and c8
# Merge score: 0.160684
#
# Checking c3 with...
#
# Checking c4 with...
# c6, c7, c8, ...
# Found connecting edges between c4 and c8
# Merge score: 0.665754
# ..., c13, c15, c22, ...
# Found connecting edges between c4 and c22
# Merge score: 1.381192
# Better than: 0.693223
#
# Checking c6 with...
# c7, c8, c13, ...
# Found connecting edges between c6 and c13
# Merge score: 0.898897
#
# Checking c7 with...
#
# Checking c8 with...
# c13, c15, c22, ...
# Found connecting edges between c8 and c22
# Merge score: 0.532848
#
# Checking c13 with...
#
# Checking c15 with...
# Merging c4 and c22
#  91%|█████████ | 30/33 [00:43<00:03,  1.05s/it]
# Checking c0 with...
# c1, c2, c3, ...
# Found connecting edges between c0 and c3
# Merge score: 0.087269
# Better than: 0.000000
#
# Checking c1 with...
# c2, c3, c4, c6, ...
# Found connecting edges between c1 and c6
# Merge score: 0.693223
# Better than: 0.087269
# ..., c7, c8, c13, ...
# Found connecting edges between c1 and c13
# Merge score: 0.460645
#
# Checking c2 with...
# c3, c4, c6, c7, c8, ...
# Found connecting edges between c2 and c8
# Merge score: 0.160684
#
# Checking c3 with...
#
# Checking c4 with...
# c6, c7, c8, ...
# Found connecting edges between c4 and c8
# Merge score: 1.098317
# Better than: 0.693223
#
# Checking c6 with...
# c7, c8, c13, ...
# Found connecting edges between c6 and c13
# Merge score: 0.898897
#
# Checking c7 with...
#
# Checking c8 with...
#
# Checking c13 with...
# Merging c4 and c8
#  94%|█████████▍| 31/33 [00:44<00:02,  1.01s/it]
# Checking c0 with...
# c1, c2, c3, ...
# Found connecting edges between c0 and c3
# Merge score: 0.087269
# Better than: 0.000000
#
# Checking c1 with...
# c2, c3, c4, c6, ...
# Found connecting edges between c1 and c6
# Merge score: 0.693223
# Better than: 0.087269
# ..., c7, c13, ...
# Found connecting edges between c1 and c13
# Merge score: 0.460645
#
# Checking c2 with...
# c3, c4, ...
# Found connecting edges between c2 and c4
# Merge score: 0.170679
#
# Checking c3 with...
#
# Checking c4 with...
#
# Checking c6 with...
# c7, c13, ...
# Found connecting edges between c6 and c13
# Merge score: 0.898897
# Better than: 0.693223
#
# Checking c7 with...
#
# Checking c13 with...
# Merging c6 and c13
#  97%|█████████▋| 32/33 [00:45<00:00,  1.08it/s]
# Checking c0 with...
# c1, c2, c3, ...
# Found connecting edges between c0 and c3
# Merge score: 0.087269
# Better than: 0.000000
#
# Checking c1 with...
# c2, c3, c4, c6, ...
# Found connecting edges between c1 and c6
# Merge score: 1.239610
# Better than: 0.087269
#
# Checking c2 with...
# c3, c4, ...
# Found connecting edges between c2 and c4
# Merge score: 0.170679
#
# Checking c3 with...
#
# Checking c4 with...
#
# Checking c6 with...
#
# Checking c7 with...
# Merging c1 and c6
# 100%|██████████| 33/33 [00:46<00:00,  1.40s/it]

# %%
plt.figure(figsize = (8, 8))
# draw a 2-D scatter plot with result
plot2d_data(res)
