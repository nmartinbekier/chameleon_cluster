# %%
import pandas as pd

from visualization import *
from chameleon import *

# %%
df = pd.read_csv('./datasets/smileface.csv', sep=',', header=None)

# returns a pands.dataframe of cluster
res = cluster(df, 4, knn=7, m=40, alpha=2.0, verbose=True, plot=True)

# draw a 2-D scatter plot with cluster
plot2d_data(res)
# Out:
# Building kNN graph (k = 7)...
# 100%|█████████████████████████████████████████████████████████████| 644/644 [00:04<00:00, 138.38it/s]
# Begin clustering...
#   0%|                                                                         | 0/36 [00:00<?, ?it/s]
# Checking c0 with...
# c1, c2, c3, c4, c5, c6, c7, c8, ...
# Found connecting edges between c0 and c8
# Merge score: 1.029176
# Better than: 0.000000
# ..., c9, c10, c11, c12, c13, c14, c15, c16, c17, c18, c19, c20, c21, c22, ...
# Found connecting edges between c0 and c22
# Merge score: 0.995116
# ..., c23, c24, c25, c26, c27, c28, ...
# Found connecting edges between c0 and c28
# Merge score: 0.086328
# ..., c29, c30, c31, c32, c33, c34, c35, c36, c37, ...
# Found connecting edges between c0 and c37
# Merge score: 0.315606
#
# Checking c1 with...
# c2, c3, c4, c5, c6, c7, c8, c9, c10, c11, c12, c13, c14, c15, c16, c17, c18, c19, c20, c21, c22, c23, c24, ...
# Found connecting edges between c1 and c24
# Merge score: 0.480806
# ...
