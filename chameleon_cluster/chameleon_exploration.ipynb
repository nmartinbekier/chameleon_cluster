# %%
import pandas as pd

from chameleon_cluster.visualization import *
from chameleon_cluster.clustertools import *
from chameleon_cluster.graphtools import *
from chameleon_cluster.chameleon import *

# %%
df = pd.read_csv('./chameleon_cluster/datasets/Aggregation.csv', sep=' ', header=None)

# %%
#cluster(df, 7, knn=20, m=40, alpha=2.0, verbose=True, plot=True)
knn = 20
graph = knn_graph(df, knn, verbose=True)
# Out:
# Building kNN graph (k = 20)...
# 100%|██████████| 788/788 [00:03<00:00, 229.09it/s]

# %%
plt.figure(figsize = (14, 14))
plt.tight_layout()
nx.draw(graph, node_size=3)

# %%
graph.number_of_edges()
# Out:
# 8937

# %%
8937/788
# Out:
# 11.341370558375635

# %%
graph.number_of_nodes()
# Out:
# 788
